# %% [markdown]
# # Jupyter Env. Setup

# %%
import sys
sys.path.append('/Users/sambong/pjts/datamap')
sys.path.append('/Users/sambong/pjts/datamap/env/lib/python3.7/site-packages')

# %env MONGO_DBNAME=datamap
# %env DEBUG_ON=True
# Out:
# env: MONGO_DBNAME=datamap
# env: DEBUG_ON=True

# %% [markdown]
# # Package Loading

# %%
import datamap
# ============================================================ Python.
import importlib
# ============================================================ External-Library.
from bs4 import BeautifulSoup
import pandas as pd
from pandas.io.json import json_normalize
# ============================================================ My-Library.
# ============================================================ Project.
from datamap import bookmark as bk

# %%
importlib.reload(bk)

cls = bk.Bookmark()
# cls.parser()
cls.creator()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark.Bookmark.creator
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark.create_new_bookmark
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark._read_bookmark
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark._convert_bookmark_to_html
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark._merge_keywords_into_name
#
# + + + + + + + + + + + + + + + + + + + + + + + + +  datamap.bookmark._merge_keywords_into_name | Function Runtime : 18.3 (secs)
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++ datamap.bookmark._write_bookmark_from_soup
#
# + + + + + + + + + + + + + + + + + + + + + + + + +  datamap.bookmark._write_bookmark_from_soup | Function Runtime : 107.8 (msec)
#
# + + + + + + + + + + + + + + + + + + + + + + + + +  datamap.bookmark.create_new_bookmark | Function Runtime : 18.7 (secs)
#
# ...

# %%
df = cls.alldocs()

# %%
df.loc[:,['name']]
# Out:
#                                                    name
# 0                                      인체 공학 - Apple 지원
# 1                             배터리 - 성능 최대화 - Apple (KR)
# 2                            What's New in macOS Mojave
# 3                                            Instagantt
# 4                                            DuckDuckGo
# ...                                                 ...
# 1793                                        Pluralsight
# 1794                                 Software Carpentry
# 1795  Top coding bootcamp in New York and Chicago | ...
# 1796                             Khan Academy - YouTube
# 1797               [도올김용옥] 영어 수학을 왜 공부해야 하는가? - YouTube
#
# [1798 rows x 1 columns]
